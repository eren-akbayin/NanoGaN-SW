# %% [markdown]
# # D-Axis Inductance Measurement
#
# Step-response method: phase U driven at double voltage, phases V and W at negative half.
# Extracts per-phase resistance R and D-axis inductance L_d from the RL time constant.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %%
# Import the d-axis inductance measurement data
df = pd.read_csv('d-axis-inductance-2.csv', skiprows=5)

# Display the first few rows
print(df.head())
print(f"\nShape: {df.shape}")
print(f"\nColumns: {df.columns.tolist()}")
# Out:
#             Unnamed: 0 Unnamed: 1 var:/global/fDcVoltage  \
# 0             Datetime   Time [s]             fDcVoltage
# 1  2026-06-07 13:22:53        0.0      12.47088623046875
# 2  2026-06-07 13:22:53      1e-05     12.501265525817871
# 3  2026-06-07 13:22:53      2e-05     12.486076354980469
# 4  2026-06-07 13:22:53      3e-05     12.501265525817871
#
#   var:/global/uDTC/uDTC[0] var:/global/uDTC/uDTC[1] var:/global/uDTC/uDTC[2]  \
# 0                  uDTC[0]                  uDTC[1]                  uDTC[2]
# 1                   1374.0                   1374.0                   1374.0
# 2                   1374.0                   1374.0                   1374.0
# 3                   1374.0                   1374.0                   1374.0
# 4                   1374.0                   1374.0                   1374.0
#
#   var:/global/fCurrent/fCurrent[0] var:/global/fCurrent/fCurrent[1]  \
# 0                      fCurrent[0]                      fCurrent[1]
# 1                       -0.0390625                              0.0
# 2                       -0.0390625                              0.0
# 3                      -0.05859375                       0.01953125
# 4                             -0.0                       0.01953125
#
#   var:/global/fCurrent/fCurrent[2]     Unnamed: 9
# 0                      fCurrent[2]     New Values
# 1                      -0.01953125  1,1,1,1,1,1,1
# 2                       0.01953125  1,1,1,1,1,1,1
# 3                       0.01953125  1,1,1,1,1,1,1
# 4                              0.0  1,1,1,1,1,1,1
#
# Shape: (1171, 10)
#
# Columns: ['Unnamed: 0', 'Unnamed: 1', 'var:/global/fDcVoltage', 'var:/global/uDTC/uDTC[0]', 'var:/global/uDTC/uDTC[1]', 'var:/global/uDTC/uDTC[2]', 'var:/global/fCurrent/fCurrent[0]', 'var:/global/fCurrent/fCurrent[1]', 'var:/global/fCurrent/fCurrent[2]', 'Unnamed: 9']

# %%
ARR = 2749

# Map Scrutiny full-path column headers to short names by signal name
signal_map = {
    'fDcVoltage':   'v_dc',
    'uDTC[0]':      'dtc0',
    'uDTC[1]':      'dtc1',
    'uDTC[2]':      'dtc2',
    'fCurrent[0]':  'i0',
    'fCurrent[1]':  'i1',
    'fCurrent[2]':  'i2',
}
rename = {'Unnamed: 0': 'datetime', 'Unnamed: 1': 'time_s'}
for col in df.columns:
    sig = col.split('/')[-1]
    if sig in signal_map:
        rename[col] = signal_map[sig]

df_clean = df.iloc[1:].reset_index(drop=True).rename(columns=rename)

for col in ['time_s', 'v_dc', 'dtc0', 'dtc1', 'dtc2', 'i0', 'i1', 'i2']:
    df_clean[col] = pd.to_numeric(df_clean[col])

df_clean['duty0'] = df_clean['dtc0'] / ARR
df_clean['duty1'] = df_clean['dtc1'] / ARR
df_clean['duty2'] = df_clean['dtc2'] / ARR

# Phase voltages referenced to DC midpoint: V_ph = (duty - 0.5) * V_dc
df_clean['U_u'] = (df_clean['duty0'] - 0.5) * df_clean['v_dc']
df_clean['U_v'] = (df_clean['duty1'] - 0.5) * df_clean['v_dc']
df_clean['U_w'] = (df_clean['duty2'] - 0.5) * df_clean['v_dc']

print(df_clean[['time_s', 'v_dc', 'dtc0', 'duty0', 'U_u', 'U_v', 'U_w']].head(10))
print(f"\nPhase voltage stats:")
print(df_clean[['U_u', 'U_v', 'U_w']].describe())
# Out:
#     time_s       v_dc    dtc0     duty0       U_u       U_v       U_w
# 0  0.00000  12.470886  1374.0  0.499818 -0.002268 -0.002268 -0.002268
# 1  0.00001  12.501266  1374.0  0.499818 -0.002274 -0.002274 -0.002274
# 2  0.00002  12.486076  1374.0  0.499818 -0.002271 -0.002271 -0.002271
# 3  0.00003  12.501266  1374.0  0.499818 -0.002274 -0.002274 -0.002274
# 4  0.00004  12.455696  1374.0  0.499818 -0.002265 -0.002265 -0.002265
# 5  0.00005  12.501266  1374.0  0.499818 -0.002274 -0.002274 -0.002274
# 6  0.00006  12.486076  1374.0  0.499818 -0.002271 -0.002271 -0.002271
# 7  0.00007  12.486076  1374.0  0.499818 -0.002271 -0.002271 -0.002271
# 8  0.00008  12.486076  1374.0  0.499818 -0.002271 -0.002271 -0.002271
# 9  0.00009  12.486076  1374.0  0.499818 -0.002271 -0.002271 -0.002271
#
# Phase voltage stats:
#                U_u          U_v          U_w
# count  1170.000000  1170.000000  1170.000000
# mean      1.093888    -0.552617    -0.552617
# std       1.079892     0.542179     0.542179
# min      -0.002296    -1.096903    -1.096903
# 25%      -0.002271    -1.086228    -1.086228
# 50%       2.138167    -1.076887    -1.076887
# 75%       2.156713    -0.002271    -0.002271
# max       2.177910    -0.002254    -0.002254

# %%
t = df_clean['time_s']

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 7), sharex=True)

ax1.plot(t, df_clean['U_u'], label='U_u')
ax1.plot(t, df_clean['U_v'], label='U_v')
ax1.plot(t, df_clean['U_w'], label='U_w')
ax1.set_ylabel('Phase Voltage (V)')
ax1.set_title('Phase Voltages (ref. DC midpoint)')
ax1.legend()
ax1.grid(True)

ax2.plot(t, df_clean['i0'], label='I_u')
ax2.plot(t, df_clean['i1'], label='I_v')
ax2.plot(t, df_clean['i2'], label='I_w')
ax2.set_ylabel('Phase Current (A)')
ax2.set_xlabel('Time (s)')
ax2.set_title('Phase Currents')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.show()

# %%
# ── Step detection ────────────────────────────────────────────────────────────
step_idx = df_clean['U_u'].diff().abs().idxmax()
t_step   = df_clean.loc[step_idx, 'time_s']
print(f"Step detected at t = {t_step:.6f} s (row {step_idx})")

# ── Pre / post windows ────────────────────────────────────────────────────────
PRE_PTS  = 20
df_pre   = df_clean.iloc[max(0, step_idx - PRE_PTS) : step_idx]
df_post  = df_clean.loc[step_idx:]

U_line_pre  = (df_pre['U_u']  - df_pre['U_v']).mean()
U_line_post = (df_post['U_u'] - df_post['U_v']).mean()
delta_U_line = U_line_post - U_line_pre

i_pre = df_pre['i0'].mean()

# ── Exponential fit on phase-U current ────────────────────────────────────────
# Model: i(t) = i_pre + Δi·(1 − exp(−t/τ))
def exp_rise(t, delta_i, tau):
    return i_pre + delta_i * (1.0 - np.exp(-t / tau))

t_fit = (df_post['time_s'] - t_step).values
i_fit = df_post['i0'].values

delta_i_guess = i_fit[-1] - i_pre
tau_guess     = t_fit[-1] / 5

popt, pcov = curve_fit(exp_rise, t_fit, i_fit,
                       p0=[delta_i_guess, tau_guess],
                       maxfev=10000)
delta_i_fit, tau_fit = popt
perr = np.sqrt(np.diag(pcov))

# ── Parameter extraction ──────────────────────────────────────────────────────
# Y-connected motor, neutral floating:
#   U_u − U_v = (3/2)·R·i + (3/2)·L·di/dt
#   → R = (2/3)·ΔU_line / Δi   (steady state)
#   → L = τ · R
R_phase = (2.0 / 3.0) * delta_U_line / delta_i_fit
L_phase = tau_fit * R_phase

print(f"\nFit:  Δi = {delta_i_fit:.4f} A  (±{perr[0]:.4f})")
print(f"      τ  = {tau_fit*1e3:.4f} ms  (±{perr[1]*1e3:.4f})")
print(f"      ΔU_line = {delta_U_line:.4f} V")
print(f"\n=== Phase Parameters ===")
print(f"  R = {R_phase*1e3:.3f} mΩ")
print(f"  L = {L_phase*1e6:.3f} µH")

# ── Plot: measured vs fitted ──────────────────────────────────────────────────
t_dense  = np.linspace(t_fit[0], t_fit[-1], 1000)
i_model  = exp_rise(t_dense, *popt)
i_ss_abs = i_pre + delta_i_fit

fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(t_fit * 1e3,   i_fit,   label='I_u measured', alpha=0.8)
ax.plot(t_dense * 1e3, i_model, 'r--', label=f'Fit  τ = {tau_fit*1e3:.3f} ms')
ax.axhline(i_ss_abs, color='gray', linestyle=':', label=f'i_ss = {i_ss_abs:.3f} A')
ax.set_xlabel('Time since step (ms)')
ax.set_ylabel('Current (A)')
ax.set_title(f'Phase U Step Response  —  R = {R_phase*1e3:.3f} mΩ,  L = {L_phase*1e6:.3f} µH')
ax.legend()
ax.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Step detected at t = 0.005760 s (row 576)
#
# Fit:  Δi = 3.9841 A  (±0.0018)
#       τ  = 0.3350 ms  (±0.0012)
#       ΔU_line = 3.2431 V
#
# === Phase Parameters ===
#   R = 542.678 mΩ
#   L = 181.800 µH
